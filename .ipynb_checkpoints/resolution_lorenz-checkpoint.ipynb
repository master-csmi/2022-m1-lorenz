# %% [markdown]
# # Système de Lorenz

# %% [markdown]
# ## Discrétisation du problème (par différence finie)

# %% [markdown]
# Système de Lorenz :
# $$\left\{\begin{align}
#     x'&=\sigma(y-x) \\
#     y'&=x(r-z)-y \\
#     z'&=xy-bz
# \end{align}\right.$$

# %% [markdown]
# On va utiliser la méthode des différences finis.
#
# On commence par découper l'intervalle $[0,T]$ en $N+1$ points de discrétisations (donc $N$ intervalles).
#
# Ainsi, on a que $\Delta t=\frac{T}{N}$. Pour $n=\{0,\dots,N\}$, on note
#
# $$\left\{\begin{align}
#     x_n&=n\Delta t \\
#     y_n&=n\Delta t \\
#     z_n&=n\Delta t
# \end{align}\right.$$
#
# Par développement de Taylor, on aura :
#
# $$\begin{align}
# &&x(t+\Delta t)&=x(t)+\Delta t x'(t) + O(\Delta t^2) \\
# \Rightarrow&& \quad x'(t)&=\frac{x(t+\Delta t)-x(t)}{\Delta t} + O(\Delta t) \\
# \Rightarrow&& \quad \partial_t x_n&\approx\frac{x_{n+1}-x_n}{\Delta t} \\
# \end{align}
# $$
#
# De même,
#
# $$\partial_t y_n\approx\frac{y_{n+1}-y_n}{\Delta t} \quad et \quad \partial_t z_n\approx\frac{z_{n+1}-z_n}{\Delta t}$$
#
# Après avoir posé les conditions initialles $(x_0,y_0,z_0)$, on a pour $n=0,\dots,N-1$ :
#
# $$\left\{\begin{align}
#     \frac{x_{n+1}-x_n}{\Delta t}&=\sigma(y_n-x_n) \\
#     \frac{y_{n+1}-y_n}{\Delta t}&=x_n(r-z_n)-y_n \\
#     \frac{z_{n+1}-z_n}{\Delta t}&=x_ny_n-bz_n
# \end{align}\right.$$
#
# et donc
#
# $$\left\{\begin{align}
#     x_{n+1}&=\sigma\Delta t y_n+(1-\sigma\Delta t) x_n \\
#     y_{n+1}&=\Delta t x_n(r-z_n)(1-\Delta t)y_n \\
#     z_{n+1}&=\Delta t x_ny_n+(1-b\Delta t)z_n
# \end{align}\right.$$

# %% [markdown]
# ## Résolution numérique

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def solve_lorenz(σ,b,r,x0,y0,z0,N,T): #on a N+1 points de discrétisation
    dt=T/N
    x=[x0]
    y=[y0]
    z=[z0]
    for n in range(1,N+1):
        x.append(σ*dt*y[n-1]+(1-σ*dt)*x[n-1])
        y.append(dt*x[n-1]*(r-z[n-1])+(1-dt)*y[n-1])
        z.append(dt*x[n-1]*y[n-1]+(1-dt*b)*z[n-1])
    return x,y,z

# %% [markdown]
# Référence pour le graphiques (avec r=28) :
#
# https://www.ijpam.eu/contents/2013-83-1/9/9.pdf

# %%
σ=10.
b=8./3
r=28

N=5000
T=N*0.005

x0=1.2
y0=1.3
z0=1.6

# %%
#t=np.linspace(0,T,N+1)
n=np.arange(0,N+1,1)
x,y,z=solve_lorenz(σ,b,r,x0,y0,z0,N,T)

fig,axs = plt.subplots(1, 2,figsize=(18,6))

axs[0].plot(n,x)
axs[0].set_xlabel("n")
axs[0].set_ylabel("x")

axs[1].plot(x,y)
axs[1].set_xlabel("x(t)")
axs[1].set_ylabel("y(t)")
# Out:
# Text(0, 0.5, 'y(t)')

# %% [markdown]
# Référence 3 :
#
# https://ftp.emc.ncep.noaa.gov/mmb/sref/Doc/lorenz_fcst.pdf

# %%
σ=10.
b=8./3
r=28

N=5000
T=30

x0=5
y0=5
z0=5

# %%
t=np.linspace(0,T,N+1)
x,y,z=solve_lorenz(σ,b,r,x0,y0,z0,N,T)

fig,ax=plt.subplots(figsize=(15,10))
ax.plot(t,x,"g",label="x(t)")
ax.plot(t,y,"b",label="y(t)")
ax.plot(t,z,"r",label="z(t)")
ax.set_xlabel("t")
ax.set_ylabel("x,y,z")
ax.legend()
